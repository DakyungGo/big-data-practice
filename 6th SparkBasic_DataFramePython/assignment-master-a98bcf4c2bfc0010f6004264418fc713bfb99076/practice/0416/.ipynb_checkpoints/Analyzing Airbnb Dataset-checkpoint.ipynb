# %%
import pandas as pd
import numpy as np


df_air = pd.read_csv('airbnb.csv') #파일 읽기
df_air['overall_satisfaction'] = df_air.overall_satisfaction.fillna(3)
df1 = df_air.copy()
idx1 =  list(df1[['room_id', 'host_id']].itertuples(index=False, name=None)) #(room_id, host_id) index 생성
df1['total_score'] = df1['overall_satisfaction'] + df1['reviews']*0.378 #total_score 생성
df1 = pd.DataFrame(df1['total_score'].to_list(), index = idx1, columns=['total_score']) #DataFrame

df1 = df1.sort_values(by=['total_score'], ascending=True) #total_score기준 오름차순 정렬
file_name = "./sorted_total_score_ascend.csv"
df1.to_csv(file_name)

df1 = df1.sort_values(by=['total_score'], ascending=False) #total_score기준 내림차순 정렬
df1
#file_name = "./sorted_total_score_descend.csv"
#df1.to_csv(file_name)
# Out:
#                       total_score
# (66288, 324630)           149.530
# (414419, 2027295)         111.474
# (1497879, 2776892)        110.718
# (31796, 119019)           103.536
# (815639, 3637081)          98.622
# ...                           ...
# (10730102, 32150958)        3.000
# (13028899, 43544288)        3.000
# (12969495, 4605418)         3.000
# (8761060, 45942466)         3.000
# (11757251, 26873897)        2.134
#
# [3277 rows x 1 columns]

# %%
df_neigh = df_air.set_index(['neighborhood']).sort_index(axis=0) #index 지정 및 오름차순 정렬
df_neigh = df_neigh.groupby('neighborhood').agg({'reviews': ['mean','max','min'],
                                    'overall_satisfaction':['mean'],
                                    'price':['mean','max','min']})
df_neigh
#file_name = "./sorted_neighborhood_factors.csv"
#df_neigh.to_csv(file_name)
# Out:
#                            reviews          overall_satisfaction       price  \
#                               mean  max min                 mean        mean
# neighborhood
# Allston                  10.314010  118   0             3.710145  100.019324
# Back Bay                 11.296820  283   0             3.955830  237.515901
# Bay Village              10.947368   47   0             3.947368  254.157895
# Beacon Hill              17.800000  214   0             4.087805  215.907317
# Brighton                 13.250000  152   0             3.850000  113.955556
# Charlestown              24.430769  198   0             4.200000  228.538462
# Chinatown                11.909091  172   0             3.854545  254.927273
# Dorchester               25.000000  262   0             4.031250   91.575000
# Downtown                 14.671053  188   0             3.921053  241.184211
# East Boston              28.531746  281   0             4.182540  115.484127
# Fenway                    8.094595  223   0             3.662162  218.770270
# Hyde Park                 9.615385   53   0             3.923077   92.576923
# Jamaica Plain            22.406349  244   0             4.177778  140.415873
# Leather District          9.125000   27   0             4.000000  342.750000
# Longwood Medical Area    52.333333  115   0             4.083333   99.333333
# Mattapan                 14.400000   69   0             3.675000   78.650000
# Mission Hill             11.346535  385   0             3.633663  132.168317
# North End                25.401515  249   0             4.140152  183.136364
# Roslindale               26.696429  147   0             4.491071   94.607143
# Roxbury                  22.802721  154   0             4.085034  148.367347
# South Boston             19.830065  192   0             4.107843  189.555556
# South Boston Waterfront   6.362319   85   0             3.579710  337.463768
# South End                14.725610  203   0             4.047256  195.106707
# West End                  8.224138   81   0             3.750000  227.258621
# West Roxbury             11.533333  155   0             3.766667  109.766667
#
#
#                             max    min
# neighborhood
# Allston                   550.0   20.0
# Back Bay                 1372.0   41.0
# Bay Village              1200.0   81.0
# Beacon Hill               849.0   42.0
# Brighton                  999.0   10.0
# Charlestown              1000.0   55.0
# Chinatown                 600.0   92.0
# Dorchester                395.0   30.0
# Downtown                 1000.0   38.0
# East Boston               300.0   35.0
# Fenway                   4000.0   25.0
# Hyde Park                 250.0   40.0
# Jamaica Plain             675.0   24.0
# Leather District          571.0  159.0
# Longwood Medical Area     149.0   60.0
# Mattapan                  169.0   44.0
# Mission Hill              872.0   27.0
# North End                 600.0   35.0
# Roslindale                250.0   40.0
# Roxbury                  1400.0   28.0
# South Boston             1000.0   47.0
# South Boston Waterfront  3000.0   95.0
# South End                1193.0   19.0
# West End                  583.0   60.0
# West Roxbury              375.0   45.0

# %%
df3 = df_air.copy()
ranged_price = [0,100,200,300,400,500,1000,5000]
ranged_price_label = ['0-100','100-200','200-300','300-400','400-500','500-1000','1000-5000']

df3 = df3.groupby(pd.cut(df_air['price'], #cut 사용해서 그룹화
                         bins=ranged_price, 
                         right=False, # right=False '미만'으로 구역 나누기
                         labels=ranged_price_label)) 
length = df3.size() # 행 개수

df3 = df3.agg({'accommodates':['mean','median'],
               'bedrooms':['mean', 'median'],
               'reviews':['mean','median'],
              'neighborhood':lambda x: list(x),
             })
                                                    
df3['length'] = length

df3 = df3.rename(columns={'neighborhood':'neighbor list','<lambda>':''}) #이름 변경
df3

#file_name = "./sorted_ranged_price.csv"
#df_neigh.to_csv(file_name)
# Out:
#           accommodates         bedrooms           reviews         \
#                   mean median      mean median       mean median
# price
# 0-100         1.974026      2  0.989796    1.0  21.000928    5.0
# 100-200       2.975787      2  1.101133    1.0  17.102502    5.0
# 200-300       3.871930      4  1.536412    1.0  13.719298    4.0
# 300-400       4.812183      5  2.005076    2.0   9.309645    4.0
# 400-500       4.488372      4  1.813953    1.0   5.441860    1.0
# 500-1000      5.322917      5  2.395833    2.0   5.635417    0.5
# 1000-5000     4.000000      4  1.909091    2.0   0.090909    0.0
#
#                                                neighbor list length
#
# price
# 0-100      [Allston, Dorchester, East Boston, Allston, Al...   1078
# 100-200    [Jamaica Plain, Beacon Hill, Beacon Hill, Miss...   1239
# 200-300    [Back Bay, Jamaica Plain, Back Bay, Beacon Hil...    570
# 300-400    [South End, South Boston Waterfront, Fenway, C...    197
# 400-500    [Mission Hill, Downtown, South Boston Waterfro...     86
# 500-1000   [Back Bay, Fenway, Back Bay, Fenway, Jamaica P...     96
# 1000-5000  [Charlestown, South Boston, Back Bay, Bay Vill...     11

# %%
import matplotlib.pyplot as plt

df4 = df3.copy()

df4['accommodates'].plot(kind='line', y='mean')

plt.show()

# %%
df4['bedrooms'].plot(kind='line', y='mean')

plt.show()

# %%
fig = plt.figure(figsize=(10,15)) #간격위해 사이즈 조정
ax1 = fig.add_subplot(3, 1, 1)
ax1.set_title('reviews average')
df_neigh['reviews'].plot(kind='line',y='mean',ax=ax1)

ax2 = fig.add_subplot(3, 1, 2)
ax2.set_title('overall_satisfaction average')
df_neigh['overall_satisfaction'].plot(kind='line',y='mean',ax=ax2)

ax3 = fig.add_subplot(3, 1, 3)
ax3.set_title('price average')
df_neigh['price'].plot(kind='line',y='mean',ax=ax3)
plt.show()
